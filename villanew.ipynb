# %% [markdown]
# <a href="https://colab.research.google.com/github/Arprarthana17/VillaProject/blob/main/villanew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4693b94d-4ee3-439f-a23d-8ae9a30a122e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4693b94d-4ee3-439f-a23d-8ae9a30a122e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !rm -rf /content/MODERN-VILLA-DATASET
# !unzip -o /content/MODERN-VILLA-DATASET-COLAB-FINAL.zip -d /content/
# Out:
# Archive:  /content/MODERN-VILLA-DATASET-COLAB-FINAL.zip
#    creating: /content/MODERN-VILLA-DATASET/
#    creating: /content/MODERN-VILLA-DATASET/blender/
#   inflating: /content/MODERN-VILLA-DATASET/blender/villa.py
#   inflating: /content/MODERN-VILLA-DATASET/.gitignore
#    creating: /content/MODERN-VILLA-DATASET/metadata/
#   inflating: /content/MODERN-VILLA-DATASET/metadata/dataset.json
#   inflating: /content/MODERN-VILLA-DATASET/README.md
#   inflating: /content/MODERN-VILLA-DATASET/modern_villa_colab.py

# %%
# !python3 -u /content/MODERN-VILLA-DATASET/modern_villa_colab.py
# Out:
# ...
# MODERN VILLA DATASET - COLAB
# ...
#
# STEP 1 - INSTALLING BLENDER
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu noble InRelease' does not seem to provide it (sources.list entry misspelt?)
# Blender 4.0.2
#
# STEP 2 - INSTALLING PYTHON PACKAGES
#
# STEP 3 - BLENDER SCRIPT: /content/MODERN-VILLA-DATASET/blender/villa.py
# STEP 4 - GENERATING VILLA (11 PNG + GLB + OBJ + MTL)
# ...
# Blender 4.0.2
# RENDERING: 01_FOUNDATION
# EGL Error (0x3001): EGL_NOT_INITIALIZED: EGL is not initialized, or could not be initialized, for the specified EGL display connection.
#
# Managed to successfully fallback to surfaceless EGL rendering!
#
# EGL Error (0x3009): EGL_BAD_MATCH: Arguments are inconsistent (for example, a valid context requires buffers not supplied by a valid surface).
# EGL Error (0x3001): EGL_NOT_INITIALIZED: EGL is not initialized, or could not be initialized, for the specified EGL display connection.
#
# ...

# %%
from IPython.display import display
from PIL import Image
from pathlib import Path

image_dir = Path("/content/MODERN_VILLA_1740_CLEAN/images")

for img_path in sorted(image_dir.glob("*.png")):
    print(img_path.name)
    display(Image.open(img_path))
# Out:
# 01_FOUNDATION.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>
# 02_GROUND_FLOOR.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>
# 03_FIRST_FLOOR.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>
# 04_COLUMNS.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>
# 05_WALLS.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>
# 06_SLABS.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>
# 07_STAIRCASE.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>
# 08_WINDOWS_DOORS.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>
# 09_BALCONY_ROOF.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>
# 10_FACADE_LANDSCAPE.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>
# 11_FINAL_ASSEMBLED.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x700>

# %%
# !cd /content && zip -r MODERN_VILLA_1740_CLEAN_OUTPUT.zip MODERN_VILLA_1740_CLEAN
# Out:
#   adding: MODERN_VILLA_1740_CLEAN/ (stored 0%)
#   adding: MODERN_VILLA_1740_CLEAN/model/ (stored 0%)
#   adding: MODERN_VILLA_1740_CLEAN/model/VILLA_000001_MODERN.mtl (deflated 85%)
#   adding: MODERN_VILLA_1740_CLEAN/model/VILLA_000001_MODERN.obj (deflated 83%)
#   adding: MODERN_VILLA_1740_CLEAN/model/VILLA_000001_MODERN.glb (deflated 92%)
#   adding: MODERN_VILLA_1740_CLEAN/images/ (stored 0%)
#   adding: MODERN_VILLA_1740_CLEAN/images/09_BALCONY_ROOF.png (deflated 0%)
#   adding: MODERN_VILLA_1740_CLEAN/images/07_STAIRCASE.png (deflated 0%)
#   adding: MODERN_VILLA_1740_CLEAN/images/06_SLABS.png (deflated 0%)
#   adding: MODERN_VILLA_1740_CLEAN/images/04_COLUMNS.png (deflated 1%)
#   adding: MODERN_VILLA_1740_CLEAN/images/01_FOUNDATION.png (deflated 3%)
#   adding: MODERN_VILLA_1740_CLEAN/images/05_WALLS.png (deflated 1%)
#   adding: MODERN_VILLA_1740_CLEAN/images/10_FACADE_LANDSCAPE.png (deflated 0%)
#   adding: MODERN_VILLA_1740_CLEAN/images/03_FIRST_FLOOR.png (deflated 2%)
# ...

# %%
from google.colab import files
files.download('/content/MODERN_VILLA_1740_CLEAN_OUTPUT.zip')
